# %% [markdown]
# <h1>Demonstracija - projekt</h1>
# <br>
# Marija Kalebota Kodžoman<br>
# Voditelj: Izv. prof. dr. sc. Domagoj Jakobović<br>
# Fakultet elektrotehnike i računarstva Sveučilišta u Zagrebu<br>
# Ak. godina 2017/2018.

# %%
import sys
import numpy as np
import scipy as sp
import sklearn
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
# %pylab inline
#from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.utils.py3compat import annotate
from IPython.display import display
#from ipywidgets import FloatSlider
from ipywidgets import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from InteractiveOptimisationAlgorithms.Functions import *
from InteractiveOptimisationAlgorithms.Matrix import *
from InteractiveOptimisationAlgorithms.Test0 import *

# %% [markdown]
# ---
# **IFunction**, AbstractFunction
# * valueAt
#
# **IAlgorithm**
# * u konstruktor IFunction
# * run, prima početnu točku pretraživanja, vraća Logger
#
# **Iteration**
# * trenutni optimum - "točku x"
# * f(x)
# * redni broj iteracije
# * broj evaluacija funkcije cilja
# * "additional info"
#
# **Logger**
# * polje/lista iteracija
# * addIteration, getIteration, getIterations
# * printToFile
#
# **Drawer**
# * u konstruktor Logger
# * metode za crtanje animacije nad funkcijama:
#     * jedne varijable
#     * dvije varijable, contour plot
#     * dvije varijable, 3D prikaz
# ---

# %%
f3 = F3OneDimensional()

# %% [markdown]
# f3(x) = (x - 3)^2

# %%
elements = np.array([[10]])
tocka = Matrix(1, 1, elements)
rjesenjeHookeJeeves, loggerHookeJeeves = HookeJeeves.run(f3, tocka, 1, 0.1, 1E-6, False)
# Out:
# Konacno rjesenje Hooke-Jeevesa za pocetnu tocku 10 je [[ 3.]]

# %%
drawer = Drawer(loggerHookeJeeves)

# %%
#drawer.drawAnimation()
drawer.drawAnimation(0.0, 15.0, -5.0, 30.0, 10)

# %%
f4 = F4xcosx()

# %%
#elements = np.array([[-2.5]])
#elements = np.array([[1.5]])
elements = np.array([[-3.5]])
tocka = Matrix(1, 1, elements)

# %%
rjesenjeHookeJeeves, loggerHookeJeeves = HookeJeeves.run(f4, tocka, 0.25, 0.1, 1E-6, False)
# Out:
# Konacno rjesenje Hooke-Jeevesa za pocetnu tocku -3.5 je [[-6.4372975]]

# %%
drawer = Drawer(loggerHookeJeeves)

# %%
#drawer.drawAnimation()
drawer.drawAnimation(-5.0, 5.0, -4.0, 4.0, 20)

# %%
f1 = F1RosenbrockBananaFunction()
elements = np.array([[-1.9, 2]])
tocka = Matrix(1, 2, elements)
rjesenjeHookeJeeves, loggerHookeJeeves = HookeJeeves.run(f1, tocka, 1, 0.1, 1E-6, False)
# Out:
# Konacno rjesenje Hooke-Jeevesa za pocetnu tocku -1.9 je [[ 1.  1.]]

# %%
#drawer.drawAnimationContour()
drawer.drawAnimationContour(-6.0, 6.0, -6.0, 6.0, 20)
# Out:
# C:\Users\Marija\Anaconda2\lib\site-packages\traitlets\traitlets.py:565: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   silent = bool(old_value == new_value)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np

def f(x, y):
    #return np.sin(np.sqrt(x ** 2 + y ** 2))
    return 100 * (y - x**2)**2 + (1 - x)**2

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
#plt.plot([-1.9], [2.0], 'b')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plot
import numpy as np

fig = plot.figure()
ax = fig.gca(projection='3d')

s = 0.05   # Try s=1, 0.25, 0.1, or 0.05
X = np.arange(-2, 2.+s, s)   #Could use linspace instead if dividing
Y = np.arange(-2, 3.+s, s)   #evenly instead of stepping...
    
#Create the mesh grid(s) for all X/Y combos.
X, Y = np.meshgrid(X, Y)

#Rosenbrock function w/ two parameters using numpy Arrays
Z = (1.-X)**2 + 100.*(Y-X*X)**2

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
         linewidth=0, antialiased=False)  #Try coolwarm vs jet

 
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

#Displays the figure, handles user interface, returns when user closes window
plot.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-045a1a7dac60> in <module>()
#       1 fig = plt.figure()
#       2 ax = fig.gca(projection='3d')
# ----> 3 X, Y, Z = axes3d.get_test_data(0.05)
#       4 ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
#       5 cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
#
# NameError: name 'axes3d' is not defined
