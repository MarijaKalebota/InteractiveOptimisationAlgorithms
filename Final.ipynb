# %%
import sys
import numpy as np
import scipy as sp
import sklearn
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
# %pylab inline
#from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.utils.py3compat import annotate
from IPython.display import display
#from ipywidgets import FloatSlider
from ipywidgets import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from InteractiveOptimisationAlgorithms.Functions import *
from InteractiveOptimisationAlgorithms.Matrix import *
from InteractiveOptimisationAlgorithms.Test0 import *
#import InteractiveOptimisationAlgorithms

# %%
f3 = F3OneDimensional()

# %%
f3OneDimensional1 = F3OneDimensional()
f3OneDimensional12 = F3OneDimensional()
elements = np.array([[10]])
tocka1 = Matrix(1, 1, elements)
tocka12 = Matrix.copyPoint(tocka1)
interval = ZlatniRez.provediZlatniRezSPocTockom(tocka1.getElement(0,0), 1E-6, f3OneDimensional1, True)
rjesenjeHookeJeeves, loggerHookeJeeves = HookeJeeves.provediHookeJeeves(f3OneDimensional12, tocka12, 1, 0.5, 1E-6, True)
# Out:
# 1
# 1
# Usao sam u provodenje zlatnog reza
# Izasao sam iz trazenja unimodalnog intervala
# Unimodalni interval. a = -6	b = 6
# k = 0.61803398875
# c = -1.416407865	d = 1.416407865
# Iteracija: 1
# c = -1.416407865	d = 1.416407865
# d je bolji od c
# Novi a = -1.416407865	c = 1.416407865	d = 3.16718427	 b = 6
# Iteracija: 2
# c = 1.416407865	d = 3.16718427
# d je bolji od c
# Novi a = 1.416407865	c = 3.16718427	d = 4.249223595	 b = 6
# Iteracija: 3
# c = 3.16718427	d = 4.249223595
# c je bolji od d
# Novi a = 1.416407865	c = 2.49844718999	d = 3.16718427	 b = 4.249223595
# Iteracija: 4
# c = 2.49844718999	d = 3.16718427
# d je bolji od c
# Novi a = 2.49844718999	c = 3.16718427	d = 3.58048651499	 b = 4.249223595
# Iteracija: 5
# c = 3.16718427	d = 3.58048651499
# c je bolji od d
# Novi a = 2.49844718999	c = 2.91174943498	d = 3.16718427	 b = 3.58048651499
# Iteracija: 6
# c = 2.91174943498	d = 3.16718427
# c je bolji od d
# Novi a = 2.49844718999	c = 2.75388202502	d = 2.91174943498	 b = 3.16718427
# Iteracija: 7
# c = 2.75388202502	d = 2.91174943498
# d je bolji od c
# Novi a = 2.75388202502	c = 2.91174943498	d = 3.00931686005	 b = 3.16718427
# Iteracija: 8
# c = 2.91174943498	d = 3.00931686005
# d je bolji od c
# Novi a = 2.91174943498	c = 3.00931686005	d = 3.06961684493	 b = 3.16718427
# Iteracija: 9
# c = 3.00931686005	d = 3.06961684493
# c je bolji od d
# Novi a = 2.91174943498	c = 2.97204941986	d = 3.00931686005	 b = 3.06961684493
# Iteracija: 10
# c = 2.97204941986	d = 3.00931686005
# d je bolji od c
# Novi a = 2.97204941986	c = 3.00931686005	d = 3.03234940475	 b = 3.06961684493
# Iteracija: 11
# c = 3.00931686005	d = 3.03234940475
# c je bolji od d
# Novi a = 2.97204941986	c = 2.99508196457	d = 3.00931686005	 b = 3.03234940475
# Iteracija: 12
# c = 2.99508196457	d = 3.00931686005
# c je bolji od d
# Novi a = 2.97204941986	c = 2.98628431534	d = 2.99508196457	 b = 3.00931686005
# Iteracija: 13
# c = 2.98628431534	d = 2.99508196457
# d je bolji od c
# Novi a = 2.98628431534	c = 2.99508196457	d = 3.00051921082	 b = 3.00931686005
# Iteracija: 14
# c = 2.99508196457	d = 3.00051921082
# d je bolji od c
# Novi a = 2.99508196457	c = 3.00051921082	d = 3.0038796138	 b = 3.00931686005
# Iteracija: 15
# c = 3.00051921082	d = 3.0038796138
# c je bolji od d
# Novi a = 2.99508196457	c = 2.99844236755	d = 3.00051921082	 b = 3.0038796138
# Iteracija: 16
# c = 2.99844236755	d = 3.00051921082
# d je bolji od c
# Novi a = 2.99844236755	c = 3.00051921082	d = 3.00180277054	 b = 3.0038796138
# Iteracija: 17
# c = 3.00051921082	d = 3.00180277054
# c je bolji od d
# Novi a = 2.99844236755	c = 2.99972592728	d = 3.00051921082	 b = 3.00180277054
# Iteracija: 18
# c = 2.99972592728	d = 3.00051921082
# c je bolji od d
# Novi a = 2.99844236755	c = 2.99923565109	d = 2.99972592728	 b = 3.00051921082
# Iteracija: 19
# c = 2.99923565109	d = 2.99972592728
# d je bolji od c
# Novi a = 2.99923565109	c = 2.99972592728	d = 3.00002893463	 b = 3.00051921082
# Iteracija: 20
# c = 2.99972592728	d = 3.00002893463
# d je bolji od c
# Novi a = 2.99972592728	c = 3.00002893463	d = 3.00021620347	 b = 3.00051921082
# Iteracija: 21
# c = 3.00002893463	d = 3.00021620347
# c je bolji od d
# Novi a = 2.99972592728	c = 2.99991319612	d = 3.00002893463	 b = 3.00021620347
# Iteracija: 22
# c = 2.99991319612	d = 3.00002893463
# d je bolji od c
# Novi a = 2.99991319612	c = 3.00002893463	d = 3.00010046496	 b = 3.00021620347
# Iteracija: 23
# c = 3.00002893463	d = 3.00010046496
# c je bolji od d
# Novi a = 2.99991319612	c = 2.99998472645	d = 3.00002893463	 b = 3.00010046496
# Iteracija: 24
# c = 2.99998472645	d = 3.00002893463
# c je bolji od d
# Novi a = 2.99991319612	c = 2.9999574043	d = 2.99998472645	 b = 3.00002893463
# Iteracija: 25
# c = 2.9999574043	d = 2.99998472645
# d je bolji od c
# Novi a = 2.9999574043	c = 2.99998472645	d = 3.00000161247	 b = 3.00002893463
# Iteracija: 26
# c = 2.99998472645	d = 3.00000161247
# d je bolji od c
# Novi a = 2.99998472645	c = 3.00000161247	d = 3.00001204861	 b = 3.00002893463
# Iteracija: 27
# c = 3.00000161247	d = 3.00001204861
# c je bolji od d
# Novi a = 2.99998472645	c = 2.99999516259	d = 3.00000161247	 b = 3.00001204861
# Iteracija: 28
# c = 2.99999516259	d = 3.00000161247
# d je bolji od c
# Novi a = 2.99999516259	c = 3.00000161247	d = 3.00000559872	 b = 3.00001204861
# Iteracija: 29
# c = 3.00000161247	d = 3.00000559872
# c je bolji od d
# Novi a = 2.99999516259	c = 2.99999914883	d = 3.00000161247	 b = 3.00000559872
# Iteracija: 30
# c = 2.99999914883	d = 3.00000161247
# c je bolji od d
# Novi a = 2.99999516259	c = 2.99999762622	d = 2.99999914883	 b = 3.00000161247
# Iteracija: 31
# c = 2.99999762622	d = 2.99999914883
# d je bolji od c
# Novi a = 2.99999762622	c = 2.99999914883	d = 3.00000008986	 b = 3.00000161247
# Iteracija: 32
# c = 2.99999914883	d = 3.00000008986
# d je bolji od c
# Novi a = 2.99999914883	c = 3.00000008986	d = 3.00000067145	 b = 3.00000161247
# Iteracija: 33
# c = 3.00000008986	d = 3.00000067145
# c je bolji od d
# Novi a = 2.99999914883	c = 2.99999973042	d = 3.00000008986	 b = 3.00000067145
# Iteracija: 34
# c = 2.99999973042	d = 3.00000008986
# d je bolji od c
# Novi a = 2.99999973042	c = 3.00000008986	d = 3.00000031201	 b = 3.00000067145
#
# Konacni rezultat zlatnog reza: [2.99999973042][3.00000067145]
# 1
# 1
# 1
# Iteracija: 1
# 1
# 1
# xb =
# [
# [ 10	]
# ]
#
# 	xp =
# [
# [ 10	]
# ]
#
# 	xn =
# [
# [ 9	]
# ]
#
# Pomak = 1
# 1
# 1
# 1
# 1
# Iteracija: 2
# 1
# 1
# xb =
# [
# [ 9	]
# ]
#
# 	xp =
# [
# [ 8.0	]
# ]
#
# 	xn =
# [
# [ 7.0	]
# ]
#
# Pomak = 1
# 1
# 1
# 1
# 1
# Iteracija: 3
# 1
# 1
# xb =
# [
# [ 7.0	]
# ]
#
# 	xp =
# [
# [ 5.0	]
# ]
#
# 	xn =
# [
# [ 4.0	]
# ]
#
# Pomak = 1
# 1
# 1
# 1
# 1
# Iteracija: 4
# 1
# 1
# xb =
# [
# [ 4.0	]
# ]
#
# 	xp =
# [
# [ 1.0	]
# ]
#
# 	xn =
# [
# [ 2.0	]
# ]
#
# Pomak = 1
# Changing pomak to 0.5
# 1
# 1
# Iteracija: 5
# 1
# 1
# xb =
# [
# [ 4.0	]
# ]
#
# 	xp =
# [
# [ 4.0	]
# ]
#
# 	xn =
# [
# [ 3.5	]
# ]
#
# Pomak = 0.5
# 1
# 1
# 1
# 1
# Iteracija: 6
# 1
# 1
# xb =
# [
# [ 3.5	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.5
# 1
# 1
# 1
# 1
# Iteracija: 7
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 2.5	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.5
# Changing pomak to 0.25
# 1
# 1
# Iteracija: 8
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.25
# Changing pomak to 0.125
# 1
# 1
# Iteracija: 9
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.125
# Changing pomak to 0.0625
# 1
# 1
# Iteracija: 10
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.0625
# Changing pomak to 0.03125
# 1
# 1
# Iteracija: 11
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.03125
# Changing pomak to 0.015625
# 1
# 1
# Iteracija: 12
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.015625
# Changing pomak to 0.0078125
# 1
# 1
# Iteracija: 13
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.0078125
# Changing pomak to 0.00390625
# 1
# 1
# Iteracija: 14
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.00390625
# Changing pomak to 0.001953125
# 1
# 1
# Iteracija: 15
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.001953125
# Changing pomak to 0.0009765625
# 1
# 1
# Iteracija: 16
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.0009765625
# Changing pomak to 0.00048828125
# 1
# 1
# Iteracija: 17
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.00048828125
# Changing pomak to 0.000244140625
# 1
# 1
# Iteracija: 18
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.000244140625
# Changing pomak to 0.0001220703125
# 1
# 1
# Iteracija: 19
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 0.0001220703125
# Changing pomak to 6.103515625e-05
# 1
# 1
# Iteracija: 20
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 6.103515625e-05
# Changing pomak to 3.0517578125e-05
# 1
# 1
# Iteracija: 21
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 3.0517578125e-05
# Changing pomak to 1.52587890625e-05
# 1
# 1
# Iteracija: 22
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 1.52587890625e-05
# Changing pomak to 7.62939453125e-06
# 1
# 1
# Iteracija: 23
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 7.62939453125e-06
# Changing pomak to 3.81469726562e-06
# 1
# 1
# Iteracija: 24
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 3.81469726562e-06
# Changing pomak to 1.90734863281e-06
# 1
# 1
# Iteracija: 25
# 1
# 1
# xb =
# [
# [ 3.0	]
# ]
#
# 	xp =
# [
# [ 3.0	]
# ]
#
# 	xn =
# [
# [ 3.0	]
# ]
#
# Pomak = 1.90734863281e-06
# Changing pomak to 9.53674316406e-07
# 1
# 1
# Konacno rjesenje Hooke-Jeevesa za pocetnu tocku 10 je [[ 3.]]

# %%
drawer = Drawer(loggerHookeJeeves)

# %%
drawer.drawAnimation()
